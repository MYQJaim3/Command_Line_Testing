# %% [markdown]
# <a href="https://colab.research.google.com/github/MYQJaim3/Command_Line_Testing/blob/main/Module_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install prophet

# %%
# Import the required libraries and dependencies
import pandas as pd
import datetime as dt
from prophet import Prophet


# %matplotlib inline

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-88948fe5-b1e8-43d3-bdf9-2993a3b58a8f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-88948fe5-b1e8-43d3-bdf9-2993a3b58a8f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Store the data in a Pandas DataFrame
# Set the "Date" column as the Datetime Index.

df_mercado_trends = pd.read_csv(
    "https://static.bc-edx.com/ai/ail-v-1-0/m8/lms/datasets/google_hourly_search_trends.csv",
    index_col='Date',
    parse_dates=True
).dropna()

# Review the first and last five rows of the DataFrame
display(df_mercado_trends.head())
display(df_mercado_trends.tail())
# Out:
# <ipython-input-9-217fb1a948ac>:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_mercado_trends = pd.read_csv(
#                      Search Trends
# Date
# 2016-06-01 00:00:00             97
# 2016-06-01 01:00:00             92
# 2016-06-01 02:00:00             76
# 2016-06-01 03:00:00             60
# 2016-06-01 04:00:00             38
#                      Search Trends
# Date
# 2020-09-07 20:00:00             71
# 2020-09-07 21:00:00             83
# 2020-09-07 22:00:00             96
# 2020-09-07 23:00:00             97
# 2020-09-08 00:00:00             96

# %%
# Review the data types of the DataFrame using the info function
df_mercado_trends.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 37106 entries, 2016-06-01 00:00:00 to 2020-09-08 00:00:00
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Search Trends  37106 non-null  int64
# dtypes: int64(1)
# memory usage: 579.8 KB

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# Slice the data to just the month of May 2020
df_may = df['2020-05']

# Plot the data
plt.figure(figsize=(10,6))
plt.plot(df_may.index, df_may['value'])  # replace 'value' with your column name
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Data for May 2020')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-3d98ff907cfa> in <cell line: 1>()
# ----> 1 df['Date'] = pd.to_datetime(df['Date'])
#       2 df.set_index('Date', inplace=True)
#       3
#       4 # Slice the data to just the month of May 2020
#       5 df_may = df['2020-05']
#
# NameError: name 'df' is not defined

# %%
# Calculate the sum of the total search traffic for May 2020
traffic_may_2020 = df_may['search_traffic'].sum()

# View the traffic_may_2020 value
print(traffic_may_2020)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-10f3518ab1b2> in <cell line: 2>()
#       1 # Calculate the sum of the total search traffic for May 2020
# ----> 2 traffic_may_2020 = df_may['search_traffic'].sum()
#       3
#       4 # View the traffic_may_2020 value
#       5 print(traffic_may_2020)
#
# NameError: name 'df_may' is not defined
